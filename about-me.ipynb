# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Charul Mathur"
reason = "they allow us to turn raw information into meaningful insights that can drive better decisions. The field is fast-growing and impactful, and I want to be a part of creating data-driven solutions."
fun_fact = "I enjoy travelling and learning new tools and technologies. My goal for this course is to strengthen my programming skills and build a solid foundation in data analytics/AI."

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Charul Mathur. I’m excited to learn because they allow us to turn raw information into meaningful insights that can drive better decisions. The field is fast-growing and impactful, and I want to be a part of creating data-driven solutions.. A fun fact about me is: I enjoy travelling and learning new tools and technologies. My goal for this course is to strengthen my programming skills and build a solid foundation in data analytics/AI..
